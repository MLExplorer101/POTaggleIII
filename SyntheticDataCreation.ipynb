# %% [markdown]
# Create syntethic annotated date for NER Customed Entities

# %%
import openai

# %%
openai.api_key = "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"

# %%
from openai import OpenAI

client = OpenAI(api_key="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")

prompt = "Create 1000 earning call sentences, making up names and financial informations \
        Create an json like the samle below to extract Reported Value, Multiplier, Currency and Granular Concept. \
        sample=[ \
          [ 'In addition to increasing our top line guidance, we're also improving our FY '24 non-GAAP operating margin \
           guidance to approximately negative 1% or an implied operating income improvement of $18 million at the midpoint of guidance.',  \
            { 'entities': [ [ 159, 175, 'GRANULAR CONCEPT' ], [ 191, 192, 'CURRENCY' ], [ 192, 194, 'REPORTED VALUE' ], [ 195, 202, 'MULTIPLIER' ] ] } ]"

completion = client.chat.completions.create(
    model="gpt-4o",
    response_format={"type": "json_object"},
    messages=[
        {"role": "system", "content": "You are a financial expert."},
        {"role": "system", "content": "Provide a valid output JSON"},

        {
            "role": "user",
            "content":  prompt
        },
    ],
)

data = completion.choices[0].message.content

print(completion.choices[0].message.content)
# Out:
# {
#   "earnings_calls": [
#     [
#       "Our fourth-quarter revenue grew by 25%, reaching $250 million, surpassing our previous forecast of $230 million.",
#       {
#         "entities": [
#           [32, 39, "GRANULAR CONCEPT"],
#           [44, 47, "REPORTED VALUE"],
#           [48, 49, "MULTIPLIER"],
#           [50, 57, "CURRENCY"]
#         ]
#       }
#     ],
#     [
#       "We expect our FY 2025 EBITDA to increase by 10%, translating into an additional $15M over our previous estimate.",
#       {
#         "entities": [
#           [14, 19, "GRANULAR CONCEPT"],
#           [47, 51, "REPORTED VALUE"],
#           [65, 68, "CURRENCY"],
#           [69, 70, "MULTIPLIER"]
#         ]
#       }
#     ],
#     [
#       "Operational costs are projected to be reduced by 5% in the coming fiscal year, saving us approximately $5 million.",
#       {
#         "entities": [
#           [0, 17, "GRANULAR CONCEPT"],
#           [54, 57, "REPORTED VALUE"],
# ...

# %%
print(data)
# Out:
# {
#   "sentences": [
#     [
#       "Our Q3 total revenue grew by 15%, leading to a record breaking $450 million.",
#       {
#         "entities": [
#           [28, 36, "GRANULAR CONCEPT"],
#           [58, 59, "CURRENCY"],
#           [59, 62, "REPORTED VALUE"],
#           [63, 70, "MULTIPLIER"]
#         ]
#       }
#     ],
#     [
#       "We expect our Q4 earnings per share to be $2.50, surpassing prior estimates.",
#       {
#         "entities": [
#           [14, 38, "GRANULAR CONCEPT"],
#           [43, 44, "CURRENCY"],
#           [44, 48, "REPORTED VALUE"]
#         ]
#       }
#     ],
#     [
#       "Carlos, our CFO, announced that our cash flow increased to €30 million this quarter.",
#       {
#         "entities": [
#           [47, 54, "GRANULAR CONCEPT"],
#           [68, 69, "CURRENCY"],
#           [69, 71, "REPORTED VALUE"],
#           [72, 79, "MULTIPLIER"]
#         ]
#       }
#     ],
#     [
# ...
